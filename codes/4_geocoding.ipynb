# %% [markdown]
# # Geocoding
#
# - Fetch latitude and longitude for flats and points of interest, based on their physical addresses

# %%
import pandas as pd
import numpy as np
import time
import datetime
import geopy.geocoders
from geopy.geocoders import Nominatim, GoogleV3, Bing
from geopy.exc import GeocoderTimedOut
from geopy.exc import GeocoderServiceError
from geopy.exc import GeopyError
import requests

# %% [markdown]
# ### Geocoding Services
#
# - I explored 4 geocoding services - Google, Bing, Nomination and OneMap
# - The first 2 are chargeable services that come with certain numbers of free requests
# - Nomination is totdally free but does not work all the time
# - OneMap is free and reliable but it is restricted to Singapore, which is enough for this project
# - For chargeable services I have removed my API Key, so the codes will NOT Work without the key

# %%
# Using Google Geocoding API to get geocodes
def get_pos_google(location_name):
    
    location_name = location_name + ' Singapore'
    geolocator = GoogleV3(api_key='###Google API Key####')
    loc = geolocator.geocode(location_name, timeout=10)
    if not loc:
        return 0,0

    return (loc.latitude, loc.longitude) 


# Using Bing Geocoding API to get geocodes
def get_pos_bing(location_name):
    
    location_name = location_name + ' Singapre'
    geolocator = Bing('****Bing API******')
    loc = geolocator.geocode(location_name,timeout=10)

    if not loc:
        return 0,0

    return (loc.latitude, loc.longitude) 


# Using Nominatim to get geocodes is FREE
def get_pos_nomination(str_location):  
    
    str_location = str_location + " Singapore"
             
    geolocator = Nominatim(user_agent='user_1')
    loc = geolocator.geocode(str_location, timeout=10)  
    if not loc:
        return 0,0
    
    return (loc.latitude, loc.longitude)

# %%
# OneMap Geocoding service provided by Singapore Government

def get_pos_onemap(str_location):
    lat=0
    lng=0
    addr = str_location.replace(' ','+')
    addr = addr.replace("st.","saint")
    
    search = 'https://developers.onemap.sg/commonapi/search?searchVal='+addr+'&returnGeom=Y&getAddrDetails=Y&pageNum=1'

    print(search)
    
    resp = requests.get(search)
    if resp.status_code == 200:
        data = resp.json()
        try:
            lat,lng = data['results'][0]['LATITUDE'],data['results'][0]['LONGITUDE']
        except:
            print('error getting geocode for '+ str_location)
    
    
    return lat,lng

# %%
# function to iterate through the hdb flat dataframe and fetch the geocodes for the flats

def update_df_hdb(df,ym):
    print('fetching lat/long and updating the dataframe .....')
  
    for i in range(len(df)):
        print(df.index[i],df.iloc[i,9])
        df.iloc[i,61], df.iloc[i,62] = get_pos_onemap(df.iloc[i,9])
    
        # 1 second break before accessing the server again to prevent overloading server"
        # This will avoid being blocked by geocoding service provider"
        time.sleep(1)
    
    d=datetime.datetime.now()
    #timestamp = str(d.year)+str(d.month)+str(d.day)+str(d.hour)+str(d.minute)+str(d.second)
    path = '../datasets/hdb/hdb_'+ym+'_'+'geocoded.csv'
    df.to_csv(path, index = False)

    print('completed for '+ym)

# %% [markdown]
# #### Load Training and Validation data and break into small chuncks
#
# The computation of lat and long take many hours. If I do it for all records at the same time and the computer will hang, so I will break them up by year.
#
# In order to avoid SettingWithCopyWarning, I will be using copy(deep=True)

# %%
# Get the hdb resale flat transactions that have been cleaned

hdb_df = pd.read_csv('../datasets/hdb/hdb_resale_2015_2020_cleaned.csv')

# %%
# create latitude and longitude columns
hdb_df['lat']=0
hdb_df['lng']=0

# %%
hdb_df['sale_date'] = pd.to_datetime(hdb_df['sale_date'])
hdb_df.dtypes

# %% [markdown]
# ### Fetch geocodes for HDB Flats
#
# It takes about 4 hours for each chunck of around 5000 records

# %%
# get 2015 data and breakup into 4 managable parts
hdb_2015 = hdb_df[hdb_df.sale_date.dt.year==2015].copy(deep=True)
hdb_2015_1 = hdb_2015.iloc[:5000,:].copy(deep=True)
hdb_2015_2 = hdb_2015.iloc[5000:10000,:].copy(deep=True)
hdb_2015_3 = hdb_2015.iloc[10000:15000,:].copy(deep=True)
hdb_2015_4 = hdb_2015.iloc[15000:,:].copy(deep=True)

# get 2016 data and break into 4 manageable parts
hdb_2016 = hdb_df[hdb_df.sale_date.dt.year==2016].copy(deep=True)
hdb_2016_1 = hdb_2016.iloc[:5000,:].copy(deep=True)
hdb_2016_2 = hdb_2016.iloc[5000:10000,:].copy(deep=True)
hdb_2016_3 = hdb_2016.iloc[10000:15000,:].copy(deep=True)
hdb_2016_4 = hdb_2016.iloc[15000:,:].copy(deep=True)

# get 2017 data and break into 4 manageable parts
hdb_2017 = hdb_df[hdb_df.sale_date.dt.year==2017].copy(deep=True)
hdb_2017_1 = hdb_2017.iloc[:5000,:].copy(deep=True)
hdb_2017_2 = hdb_2017.iloc[5000:10000,:].copy(deep=True)
hdb_2017_3 = hdb_2017.iloc[10000:15000,:].copy(deep=True)
hdb_2017_4 = hdb_2017.iloc[15000:,:].copy(deep=True)

# get 2018 data and break into 4 manageable parts
hdb_2018 = hdb_df[hdb_df.sale_date.dt.year==2018].copy(deep=True)
hdb_2018_1 = hdb_2018.iloc[:5000,:].copy(deep=True)
hdb_2018_2 = hdb_2018.iloc[5000:10000,:].copy(deep=True)
hdb_2018_3 = hdb_2018.iloc[10000:15000,:].copy(deep=True)
hdb_2018_4 = hdb_2018.iloc[15000:,:].copy(deep=True)

# get 2019 data and break into 4 manageable parts
hdb_2019 = hdb_df[hdb_df.sale_date.dt.year==2019].copy(deep=True)
hdb_2019_1 = hdb_2019.iloc[:5000,:].copy(deep=True)
hdb_2019_2 = hdb_2019.iloc[5000:10000,:].copy(deep=True)
hdb_2019_3 = hdb_2019.iloc[10000:15000,:].copy(deep=True)
hdb_2019_4 = hdb_2019.iloc[15000:,:].copy(deep=True)

# get 2020 data
hdb_2020 = hdb_df[hdb_df.sale_date.dt.year==2020].copy(deep=True)

# %%
# This csv file is used for testing purpose only
hdb_test = pd.read_csv('../datasets/hdb/hdb_test.csv')
hdb_test['lat']=0
hdb_test['lng']=0

# blocked to prevent it from running
update_df_hdb(hdb_test,'test')

# %% [markdown]
# ### Combine the files for each year into a single file
#
# The codes below are simplified to show each year's records as 4 files (based on how I have broken them down earlier). The reality is that each year has several files because the nomimation geocoding service is not reliable and sometimes it failed after just a few hundred fetches.
#
# Unfortunately the Google and Bing services are chargeable after certain number of free requests, so they are seldom used.

# %%
# Combine the files for each year after geocoding

hdb_2015_1 = pd.read_csv("../datasets/hdb/hdb_resale_2015_1_geocoded.csv")
hdb_2015_2 = pd.read_csv("../datasets/hdb/hdb_resale_2015_2_geocoded.csv")
hdb_2015_3 = pd.read_csv("../datasets/hdb/hdb_resale_2015_3_geocoded.csv")
hdb_2015_4 = pd.read_csv("../datasets/hdb/hdb_resale_2015_4_geocoded.csv")
hdb_2015_geocoded = pd.concat([hdb_2015_1,hdb_2015_2,hdb_2015_3,hdb_2015_4],ignore_index=True)

# %%
hdb_2015_geocoded.shape

# %%
#hdb_2015_geocoded.to_csv('../datasets/hdb/hdb_resale_2015_geocoded.csv',index=False)

# %% [markdown]
# ### Fetch geocodes for Points of Interest
#
# Only need to do for 2  set of POI. The rest came with the source files

# %%
# Load school dataset and update with geocodes

school_df = pd.read_csv('../datasets/poi/school_cleaned.csv')
print('fetching lat/long and updating the dataframe .....')

for i in range(len(school_df)):
    print(school_df.iloc[i,0] + ' at ' +school_df.iloc[i,3])
    school_df.iloc[i,1], school_df.iloc[i,2] = get_pos_nomination(school_df.iloc[i,3])

# school_df.to_csv('../datasets/poi/school_geocoded.csv', index = False)
# Out:
# fetching lat/long and updating the dataframe .....
# admiralty primary school at 11   woodlands circle
# admiralty secondary school at 31   woodlands crescent
# ahmad ibrahim primary school at 10   yishun street 11
# ahmad ibrahim secondary school at 751  yishun avenue 7
# ai tong school at 100  bright hill drive
# alexandra primary school at 2a   prince charles crescent
# anchor green primary school at 31   anchorvale drive
# anderson primary school at 19   ang mo kio ave 9
# anderson secondary school at 10   ang mo kio street 53
# anderson serangoon junior college at 4500 ang mo kio avenue 6
# ang mo kio primary school at 20   ang mo kio avenue 3
# ang mo kio secondary school at 6    ang mo kio street 22
# anglican high school at 600  upper changi road
# anglo-chinese junior college at 25   dover close east
# anglo-chinese school (barker road) at 60   barker road
# anglo-chinese school (independent) at 121  dover road
# anglo-chinese school (junior) at 16   winstedt road
# anglo-chinese school (primary) at 50   barker road
# angsana primary school at 3    tampines street 22
# assumption english school at 622  upper bukit timah road
# assumption pathway school at 30   cashew road
# bartley secondary school at 10   jalan bunga rampai
# beacon primary school at 36   bukit panjang ring road
# beatty secondary school at 1    toa payoh north
# bedok green primary school at 1    bedok south ave 2
# bedok green secondary school at 360  bedok north ave 3
# bedok south secondary school at 1    jalan langgar bedok
# bedok view secondary school at 6    bedok south avenue 3
# bendemeer primary school at 91   bendemeer road
# bendemeer secondary school at 1    st wilfred road
# blangah rise primary school at 91   telok blangah heights
# boon lay garden primary school at 20   boon lay drive
# boon lay secondary school at 11   jurong west street 65
# bowen secondary school at 2    lorong napiri
# broadrick secondary school at 61   dakota crescent
# bukit batok secondary school at 50   bukit batok west ave 8
# bukit merah secondary school at 10   lengkok bahru
# bukit panjang govt. high school at 7    choa chu kang ave 4
# bukit panjang primary school at 109  cashew road
# bukit timah primary school at 111  lorong kismis
# bukit view primary school at 18   bukit batok street 21
# bukit view secondary school at 16   bukit batok street 21
# canberra primary school at 21   admiralty drive
# canberra secondary school at 51   sembawang drive
# canossa catholic primary school at 1    sallim road
# cantonment primary school at 1    cantonment close
# casuarina primary school at 30   pasir ris st 41
# catholic high school at 9    bishan street 22
# catholic junior college at 129  whitley road
# cedar girls' secondary school at 1    cedar avenue
# cedar primary school at 15   cedar avenue
# changkat changi secondary school at 23   simei st 3
# changkat primary school at 11   simei st 3
# chij (katong) primary at 17   martia road
# chij (kellock) at 1    bukit teresa road
# chij katong convent at 346  marine terrace
# chij our lady of good counsel at 2c   burghley drive
# chij our lady of the nativity at 1257 upper serangoon road
# chij our lady queen of peace at 4    chestnut drive
# chij primary (toa payoh) at 628  lorong 1 toa payoh
# chij secondary (toa payoh) at 626  lorong 1 toa payoh
# chij st. joseph's convent at 62   sengkang east way
# chij st. nicholas girls' school at 501  ang mo kio street 13
# chij st. theresa's convent at 160  lower delta road
# chongfu school at 170  yishun avenue 6
# chongzheng primary school at 1    tampines street 21
# christ church secondary school at 20   woodlands drive 17
# chua chu kang primary school at 20   choa chu kang avenue 2
# chua chu kang secondary school at 3    teck whye crescent
# chung cheng high school (main) at 50   goodman road
# chung cheng high school (yishun) at 11   yishun street 61
# clementi primary school at 8    clementi ave 3
# clementi town secondary school at 10   clementi ave 3
# commonwealth secondary school at 698  west coast road
# compassvale primary school at 21   compassvale st
# compassvale secondary school at 51   compassvale crescent
# concord primary school at 3    choa chu kang ave 4
# corporation primary school at 31   jurong west street 24
# crescent girls' school at 357  tanglin road
# crest secondary school at 561  jurong east street 24
# damai primary school at 52   bedok reservoir crescent
# damai secondary school at 4800 bedok reservoir road
# dazhong primary school at 35   bukit batok street 31
# de la salle school at 11   choa chu kang st 52
# deyi secondary school at 1    ang mo kio street 42
# dunearn secondary school at 21   bukit batok west avenue 2
# dunman high school at 10   tanjong rhu road
# dunman secondary school at 21   tampines street 45
# east spring primary school at 31   tampines st 33
# east spring secondary school at 30   tampines street 34
# edgefield primary school at 41   edgefield plains
# edgefield secondary school at 36   punggol field
# elias park primary school at 11   pasir ris street 52
# endeavour primary school at 10   admiralty link
# eunoia junior college at 2    sin ming place
# eunos primary school at 95   jalan eunos
# evergreen primary school at 31   woodlands circle
# evergreen secondary school at 11   woodlands street 83
# fairfield methodist school (primary) at 100  dover road
# fairfield methodist school (secondary) at 102  dover road
# fajar secondary school at 31   gangsa road
# farrer park primary school at 2    farrer park road
# fengshan primary school at 307  bedok north road
# fern green primary school at 70   fernvale link
# fernvale primary school at 1    fernvale lane
# first toa payoh primary school at 7    lorong 8 toa payoh
# frontier primary school at 20   jurong west street 61
# fuchun primary school at 23   woodlands avenue 1
# fuchun secondary school at 21   woodlands avenue 1
# fuhua primary school at 65   jurong east street 13
# fuhua secondary school at 5    jurong west street 41
# gan eng seng primary school at 100  redhill close
# gan eng seng school at 1    henderson road
# geylang methodist school (primary) at 4    geylang east central
# geylang methodist school (secondary) at 2    geylang east central
# gongshang primary school at 1    tampines street 42
# greendale primary school at 50   edgedale plains
# greendale secondary school at 51   edgedale plains
# greenridge primary school at 11   jelapang road
# greenridge secondary school at 32   bukit panjang ring road
# greenwood primary school at 11   woodlands  dr  62
# guangyang primary school at 6    bishan street 12
# guangyang secondary school at 8    bishan street 12
# hai sing catholic school at 9    pasir ris drive 6
# haig girls' school at 51   koon seng road
# henry park primary school at 1    holland grove road
# hillgrove secondary school at 10   bukit batok street 52
# holy innocents' high school at 1191 upper serangoon road
# holy innocents' primary school at 5    lorong low koon
# hong wen school at 30   towner road
# horizon primary school at 61   edgedale plains
# hougang primary school at 1    hougang st 93
# hougang secondary school at 2    hougang street 93
# hua yi secondary school at 60   jurong west st 42
# huamin primary school at 21   yishun avenue 11
# hwa chong institution at 661  bukit timah road
# innova primary school at 80   woodlands drive 17
# jiemin primary school at 2    yishun street 71
# jing shan primary school at 5    ang mo kio st 52
# junyuan primary school at 2    tampines street 91
# junyuan secondary school at 11   tampines street 84
# jurong pioneer junior college at 21   teck whye walk
# jurong primary school at 320  jurong east street 32
# jurong secondary school at 31   yuan ching road
# jurong west primary school at 30   jurong west st 61
# jurong west secondary school at 61   jurong west street 65
# jurongville secondary school at 202  jurong east avenue 1
# juying primary school at 31   jurong west street 91
# juying secondary school at 33   jurong west street 91
# keming primary school at 90   bukit batok east avenue 6
# kent ridge secondary school at 147  west coast road
# kheng cheng school at 15   lorong 3 toa payoh
# kong hwa school at 350  guillemard road
# kranji primary school at 11   choa chu kang street 54
# kranji secondary school at 61   choa chu kang street 51
# kuo chuan presbyterian primary school at 8    bishan street 13
# kuo chuan presbyterian secondary school at 10   bishan street 13
# lakeside primary school at 161  corporation walk
# lianhua primary school at 2    bukit batok street 52
# loyang view secondary school at 12   pasir ris street 11
# maha bodhi school at 10   ubi avenue 1
# manjusri secondary school at 20   ubi avenue 1
# maris stella high school at 25   mount vernon road
# marsiling primary school at 31   woodlands centre road
# marsiling secondary school at 12   marsiling road
# marymount convent school at 20   marymount road
# mayflower primary school at 6    ang mo kio ave 2
# mayflower secondary school at 2    ang mo kio street 21
# mee toh school at 21   edgedale plains
# meridian primary school at 20   pasir ris st 71
# meridian secondary school at 31   pasir ris street 51
# methodist girls' school (primary) at 11   blackmore drive
# methodist girls' school (secondary) at 11   blackmore drive
# millennia institute at 60   bukit batok west avenue 8
# montfort junior school at 52   hougang avenue 8
# montfort secondary school at 50   hougang avenue 8
# nan chiau high school at 20   anchorvale link
# nan chiau primary school at 50   anchorvale link
# nan hua high school at 41   clementi avenue 1
# nan hua primary school at 30   jalan lempeng
# nanyang girls' high school at 2    linden drive
# nanyang junior college at 128  serangoon avenue 3
# nanyang primary school at 52   king's road
# national junior college at 37   hillcrest road
# naval base primary school at 7    yishun ave 4
# naval base secondary school at 901  yishun ring road
# new town primary school at 300  tanglin halt road
# new town secondary school at 1020 dover road
# ngee ann primary school at 344  marine terrace
# ngee ann secondary school at 1    tampines street 32
# north spring primary school at 1    rivervale street
# north view primary school at 210  yishun avenue 6
# north vista primary school at 20   compassvale link
# north vista secondary school at 11   rivervale link
# northbrooks secondary school at 585  yishun ring road
# northland primary school at 15   yishun avenue 4
# northland secondary school at 3    yishun street 22
# northlight school at 151  towner road
# northoaks primary school at 61   sembawang drive
# nus high school of mathematics and science at 20   clementi avenue 1
# oasis primary school at 71   edgefield plains
# opera estate primary school at 48   fidelio street
# orchid park secondary school at 10   yishun street 81
# outram secondary school at 3    york hill
# palm view primary school at 150  compassvale bow
# park view primary school at 60   pasir ris drive 1
# pasir ris crest secondary school at 11   pasir ris street 41
# pasir ris primary school at 5    pasir ris street 21
# pasir ris secondary school at 390  tampines street 21
# paya lebar methodist girls' school (primary) at 298  lorong ah soo
# paya lebar methodist girls' school (secondary) at 296  lor ah soo
# pei chun public school at 16   lorong 7 toa payoh
# pei hwa presbyterian primary school at 7    pei wah avenue
# pei hwa secondary school at 21   fernvale link
# pei tong primary school at 15   clementi avenue 5
# peicai secondary school at 10   serangoon avenue 4
# peirce secondary school at 10   sin ming walk
# peiying primary school at 651  yishun ring road
# ping yi secondary school at 61   chai chee street
# pioneer primary school at 23   jurong west street 81
# poi ching school at 21   tampines street 71
# presbyterian high school at 5209 ang mo kio avenue 6
# princess elizabeth primary school at 30   bukit batok west avenue 3
# punggol cove primary school at 52   sumang walk
# punggol green primary school at 98   punggol walk
# punggol primary school at 61   hougang avenue 8
# punggol secondary school at 51   edgefield plains
# punggol view primary school at 9    punggol place
# qifa primary school at 50   west coast avenue
# qihua primary school at 5    woodlands street 81
# queenstown primary school at 310  margaret dr
# queenstown secondary school at 1    strathmore road
# queensway secondary school at 2a   margaret drive
# radin mas primary school at 1    bukit purmei avenue
# raffles girls' primary school at 21   hillcrest road
# raffles girls' school (secondary) at 2    braddell rise
# raffles institution at 1    raffles institution lane
# red swastika school at 350  bedok north avenue 3
# regent secondary school at 50   choa chu kang north 5
# river valley high school at 6    boon lay avenue
# river valley primary school at 2    river valley green
# riverside primary school at 110  woodlands crescent
# riverside secondary school at 3    woodlands street 81
# rivervale primary school at 80   rivervale drive
# rosyth school at 21   serangoon north avenue 4
# rulang primary school at 6    jurong west street 52
# school of science and technology, singapore at 1    technology drive
# school of the arts, singapore at 1    zubir said drive
# sembawang primary school at 10   sembawang drive
# sembawang secondary school at 30   sembawang crescent
# seng kang primary school at 21   compassvale walk
# seng kang secondary school at 10   compassvale lane
# sengkang green primary school at 15   fernvale road
# serangoon garden secondary school at 21   serangoon north avenue 1
# serangoon secondary school at 11   upper serangoon view
# shuqun primary school at 8    jurong west street 51
# si ling primary school at 61   woodlands avenue 1
# singapore chinese girls' primary school at 190  dunearn road
# singapore chinese girls' school at 190  dunearn road
# singapore sports school at 1    champions way
# south view primary school at 6    choa chu kang central
# spectra secondary school at 1    woodlands drive 64
# springdale primary school at 71   anchorvale link
# springfield secondary school at 30   tampines avenue 8
# st. andrew's junior college at 5    sorby adams drive
# st. andrew's junior school at 2    francis thomas drive
# st. andrew's secondary school at 15   francis thomas drive
# st. anthony's canossian primary school at 1602 bedok north ave 4
# st. anthony's canossian secondary school at 1600 bedok north avenue 4
# st. anthony's primary school at 30   bukit batok st 32
# st. gabriel's primary school at 220  lorong chuan
# st. gabriel's secondary school at 24   serangoon avenue 1
# st. hilda's primary school at 2    tampines ave 3
# st. hilda's secondary school at 2    tampines street 82
# st. joseph's institution at 38   malcolm road
# st. joseph's institution junior at 3    essex road
# st. margaret's primary school at 2    mattar road
# st. margaret's secondary school at 111  farrer road
# st. patrick's school at 490  east coast road
# st. stephen's school at 20   siglap view
# stamford primary school at 1    victoria lane
# swiss cottage secondary school at 3    bukit batok street 34
# tampines meridian junior college at 21   pasir ris street 71
# tampines north primary school at 30   tampines avenue 9
# tampines primary school at 250  tampines street 12
# tampines secondary school at 252  tampines st 12
# tanglin secondary school at 301  west coast road
# tanjong katong girls' school at 20   dunman lane
# tanjong katong primary school at 860  new upper changi road
# tanjong katong secondary school at 130  haig road
# tao nan school at 49   marine crescent
# teck ghee primary school at 1    ang mo kio street 32
# teck whye primary school at 11   teck whye walk
# teck whye secondary school at 31   teck whye crescent
# telok kurau primary school at 50   bedok reservoir rd
# temasek junior college at 22   bedok south road
# temasek primary school at 501  bedok south ave 3
# temasek secondary school at 600  upper east coast road
# townsville primary school at 3    ang mo kio ave 10
# unity primary school at 21   choa chu kang crescent
# unity secondary school at 20   choa chu kang street 62
# valour primary school at 52   sumang walk
# victoria junior college at 20   marine vista
# victoria school at 2    siglap link
# waterway primary school at 70   punggol drive
# wellington primary school at 10   wellington circle
# west grove primary school at 1    jurong west st 72
# west spring primary school at 60   bukit panjang ring road
# west spring secondary school at 61   senja  road
# west view primary school at 31   senja road
# westwood primary school at 1    jurong west street 73
# westwood secondary school at 11   jurong west street 25
# white sands primary school at 2    pasir ris st 11
# whitley secondary school at 30   bishan street 24
# woodgrove primary school at 2    woodlands drive 14
# woodgrove secondary school at 3    woodlands avenue 6
# woodlands primary school at 10   woodlands drive 50
# woodlands ring primary school at 11   woodlands ring road
# woodlands ring secondary school at 10   woodlands ring road
# woodlands secondary school at 11   marsiling road
# xinghua primary school at 45   hougang avenue 1
# xingnan primary school at 5    jurong west street 91
# xinmin primary school at 9    hougang avenue 8
# xinmin secondary school at 11   hougang avenue 8
# xishan primary school at 8    yishun street 21
# yangzheng primary school at 15   serangoon avenue 3
# yew tee primary school at 10   choa chu kang st 64
# yio chu kang primary school at 1    hougang street 51
# yio chu kang secondary school at 3063 ang mo kio avenue 5
# yishun innova junior college at 3    yishun ring road
# yishun primary school at 500  yishun ring road
# yishun secondary school at 4    yishun street 71
# yishun town secondary school at 6    yishun street 21
# yu neng primary school at 56   bedok north st 3
# yuan ching secondary school at 103  yuan ching road
# yuhua primary school at 158  jurong east street 24
# yuhua secondary school at 35   jurong west street 41
# yumin primary school at 3    tampines street 21
# yusof ishak secondary school at 11   bukit batok street 25
# yuying secondary school at 47   hougang avenue 1
# zhangde primary school at 51   jalan membina
# zhenghua primary school at 9    fajar road
# zhenghua secondary school at 91   senja road
# zhonghua primary school at 12   serangoon avenue 4
# zhonghua secondary school at 13   serangoon avenue 3

# %%
# Load shopping malls dataset and update with geocodes based on malls' names 

df_malls = pd.read_csv('../datasets/poi/mall_cleaned.csv')

for i in range(len(df_malls)):
    lat, lng = get_pos_nomination(df_malls.iloc[i,0])
    df_malls.iloc[i,1] = lat
    df_malls.iloc[i,2] = lng
    time.sleep(2)

# %%
# df_malls.to_csv("../datasets/poi/mall_geocoded.csv")
